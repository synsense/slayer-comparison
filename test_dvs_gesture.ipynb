# %%
from dvs_gesture_exodus import ExodusNetwork
from data_modules.dvs_gesture import DVSGesture
import torch.nn as nn
from torch.utils.data import Subset
import torch
import pytorch_lightning as pl
from tqdm.auto import tqdm

# %%
batch_size = 4
dataset = DVSGesture(batch_size=batch_size, spatial_factor=0.5)
dataset.setup()
dataset.prepare_data()

# %%
# dataloader = dataset.val_dataloader()
dataloader = dataset.train_dataloader()

# %%
events = next(iter(dataloader))[0]

# %%
events.shape

# %%
for data, label in tqdm(dataloader):
    pass

# %%
data, label = next(iter(dataset.val_dataloader()))

# %%
data.shape

# %%
net = ExodusNetwork(batch_size=batch_size).cuda()

# %%
events = events.cuda()
output = net(events)

# %%
output.shape
